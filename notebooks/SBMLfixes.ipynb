# %% [markdown]
# # Format fix of g-thermo
#
# Trying to fix SBML issues in the g-thermo model
#
# Benjamín J. Sánchez, 2019-10-30
#
# ## 1. Model inspection
#
# Model is available at https://github.com/biosustain/g-thermo/blob/master/model/g-thermo.xml

# %%
import cobra

model = cobra.io.read_sbml_model("../model/g-thermo.xml")

model
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_28_c "Pyridoxal_C4H5N2O3R2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_28_c "Pyridoxal_C4H5N2O3R2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_12_c "Pyridoxal_phosphate_C4H5N2O3R2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12_c "Pyridoxal_phosphate_C4H5N2O3R2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_1337_c "Cob(II)yrinate-a,c-diamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_1337_c "Cob(II)yrinate-a,c-diamide">
# ...

# %% [markdown]
# ### Reactions:

# %%
model.reactions
# Out:
# [<Reaction EX_1819_e at 0x29ecf5b49c8>,
#  <Reaction EX_499_e at 0x29ed34c06c8>,
#  <Reaction EX_23_e at 0x29ed34c0848>,
#  <Reaction EX_43_e at 0x29ed34c08c8>,
#  <Reaction EX_1864_e at 0x29ed34c0ac8>,
#  <Reaction EX_85_e at 0x29ed34c0e08>,
#  <Reaction EX_140_e at 0x29ed34c0c48>,
#  <Reaction EX_408_e at 0x29ecf585d08>,
#  <Reaction EX_14_e at 0x29ecf578108>,
#  <Reaction EX_29_e at 0x29ed34c0888>,
#  <Reaction EX_280_e at 0x29ed34c6108>,
#  <Reaction EX_1754_e at 0x29ed34c6208>,
#  <Reaction EX_1755_e at 0x29ed34c6388>,
#  <Reaction EX_1_e at 0x29ed34c6508>,
#  <Reaction EX_7_e at 0x29ed34c6688>,
#  <Reaction EX_11_e at 0x29ed34c6808>,
#  <Reaction EX_71_e at 0x29ed34c6988>,
#  <Reaction EX_209_e at 0x29ed34c6b08>,
#  <Reaction EX_179_e at 0x29ed34c6dc8>,
#  <Reaction EX_37_e at 0x29ecf573f48>,
#  <Reaction EX_55_e at 0x29ed34c6e88>,
#  <Reaction EX_45_e at 0x29ed34c6fc8>,
#  <Reaction EX_357_e at 0x29ed34cb088>,
#  <Reaction EX_452_e at 0x29ed34cb2c8>,
# ...

# %%
model.reactions.EX_29_e
# Out:
# <Reaction EX_29_e at 0x29ed34c0888>

# %% [markdown]
# ### Metabolites:

# %%
model.metabolites
# Out:
# [<Metabolite 28_c at 0x29ecf55ea48>,
#  <Metabolite 12_c at 0x29ecf55edc8>,
#  <Metabolite 1337_c at 0x29ecf55e3c8>,
#  <Metabolite 1864_c at 0x29ecf55ee88>,
#  <Metabolite 1066_c at 0x29ecf563148>,
#  <Metabolite 1819_e at 0x29ecf563588>,
#  <Metabolite 742_c at 0x29ecf5632c8>,
#  <Metabolite 1825_c at 0x29ecf563348>,
#  <Metabolite 653_c at 0x29ecf563d88>,
#  <Metabolite 549_c at 0x29ecf563ec8>,
#  <Metabolite 499_e at 0x29ecf563e88>,
#  <Metabolite 23_e at 0x29ecf573688>,
#  <Metabolite 43_e at 0x29ecf5737c8>,
#  <Metabolite 1864_e at 0x29ecf573948>,
#  <Metabolite 1818_c at 0x29ecf573588>,
#  <Metabolite 1863_c at 0x29ecf573508>,
#  <Metabolite 1819_c at 0x29ecf573f08>,
#  <Metabolite 42_c at 0x29ecf573908>,
#  <Metabolite 35_c at 0x29ecf573e08>,
#  <Metabolite 257_c at 0x29ecf578a08>,
#  <Metabolite 258_c at 0x29ecf578b08>,
#  <Metabolite 2466_c at 0x29ecf578f88>,
#  <Metabolite 18544_c at 0x29ecf578a48>,
#  <Metabolite 1853_c at 0x29ecf578708>,
# ...

# %%
model.metabolites.get_by_id("29_e")
# Out:
# <Metabolite 29_e at 0x29ed33f1c48>

# %% [markdown]
# ### Genes:

# %%
model.genes
# Out:
# [<Gene RTMO00131 at 0x29ecf57d248>,
#  <Gene RTMO05104 at 0x29ed34320c8>,
#  <Gene RTMO02719 at 0x29ecf589608>,
#  <Gene RTMO02716 at 0x29ecf5d70c8>,
#  <Gene RTMO00549 at 0x29ed3558f88>,
#  <Gene RTMO04279 at 0x29ed2eabbc8>,
#  <Gene RTMO03052 at 0x29ecd24ca08>,
#  <Gene RTMO03053 at 0x29ecf573b88>,
#  <Gene RTMO04026 at 0x29ecf59f0c8>,
#  <Gene RTMO00138 at 0x29ecd141ac8>,
#  <Gene RTMO03630 at 0x29ecf5d0a88>,
#  <Gene RTMO00832 at 0x29ecf590dc8>,
#  <Gene RTMO00831 at 0x29ecf5b4748>,
#  <Gene RTMO00139 at 0x29ecf5b4bc8>,
#  <Gene RTMO00166 at 0x29ecf590908>,
#  <Gene RTMO02070 at 0x29ecf578088>,
#  <Gene RTMO04728 at 0x29ed2f8cf48>,
#  <Gene RTMO03022 at 0x29ecf578ac8>,
#  <Gene RTMO01074 at 0x29ecf573e48>,
#  <Gene RTMO01076 at 0x29ed359a5c8>,
#  <Gene RTMO03707 at 0x29ecf578608>,
#  <Gene RTMO00807 at 0x29ed34dd508>,
#  <Gene RTMO04339 at 0x29ed359a888>,
#  <Gene RTMO04631 at 0x29ed359a648>,
#  <Gene RTMO02826 at 0x29ed359a708>,
#  <Gene RTMO04632 at 0x29ed359a388>,
# ...

# %%
for reaction in model.reactions:
    print(reaction.gene_reaction_rule)
# Out:
# RTMO00131 or RTMO05104
# RTMO02719 or RTMO02716 or RTMO00549
# RTMO03052 or RTMO04279 or RTMO03053
# RTMO00831 or RTMO00549 or RTMO03630 or RTMO02719 or RTMO00138 or RTMO04026 or RTMO00139 or RTMO02716 or RTMO00832
# RTMO00166
# RTMO02070
# RTMO04728
# RTMO03022
# RTMO01076 or RTMO01074
# RTMO03707
# RTMO02826 or RTMO04339 or RTMO02829 or RTMO04631 or RTMO02828 or RTMO04632 or RTMO04633 or RTMO00807 or RTMO04657
# RTMO04657 or RTMO04339 or RTMO02826 or RTMO04631 or RTMO02829 or RTMO04632 or RTMO02828 or RTMO04633 or RTMO00807
# RTMO03024
# RTMO00197 or RTMO00196 or RTMO00193 or RTMO00194 or RTMO04075 or RTMO00373 or RTMO03395 or RTMO02535 or RTMO04972 or RTMO03714 or RTMO00200 or RTMO01034 or RTMO00201 or RTMO00199 or RTMO00198
# RTMO03749
# RTMO02237 or RTMO03852
# RTMO00694 or RTMO01425 or RTMO01424
# RTMO05248 or RTMO04294
# RTMO05248
# RTMO05022
# RTMO01680 or RTMO01679 or RTMO01678
# RTMO04916
# RTMO04294 or RTMO05248
# RTMO01021 or RTMO04555
# RTMO03749
# ...

# %% [markdown]
# some GPRs are non-compliant:
#
# - ( non enzymatic)
# - (RTMO02614, RTMO02615, RTMO02306, RTMO01440)
#
# so let's remove those lines in the SBML file, commit and reload:

# %%
model = cobra.io.read_sbml_model("../model/g-thermo.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_28_c "Pyridoxal_C4H5N2O3R2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_28_c "Pyridoxal_C4H5N2O3R2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_12_c "Pyridoxal_phosphate_C4H5N2O3R2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12_c "Pyridoxal_phosphate_C4H5N2O3R2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_1337_c "Cob(II)yrinate-a,c-diamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_1337_c "Cob(II)yrinate-a,c-diamide">
# ...

# %%
model.genes
# Out:
# [<Gene RTMO00131 at 0x29ed7a1f488>,
#  <Gene RTMO05104 at 0x29ed7a51048>,
#  <Gene RTMO02719 at 0x29ed7a4a548>,
#  <Gene RTMO02716 at 0x29ed74a4b48>,
#  <Gene RTMO00549 at 0x29ed7a6de88>,
#  <Gene RTMO04279 at 0x29ed7a69fc8>,
#  <Gene RTMO03052 at 0x29ed7a6df48>,
#  <Gene RTMO03053 at 0x29ed7a6dd48>,
#  <Gene RTMO04026 at 0x29ed7a6df08>,
#  <Gene RTMO00138 at 0x29ed7a6dd88>,
#  <Gene RTMO03630 at 0x29ed7a6dc08>,
#  <Gene RTMO00832 at 0x29ed7a9a248>,
#  <Gene RTMO00831 at 0x29ed7a9a088>,
#  <Gene RTMO00139 at 0x29ed7a9a0c8>,
#  <Gene RTMO00166 at 0x29ed7a6dd08>,
#  <Gene RTMO02070 at 0x29ed7a6dcc8>,
#  <Gene RTMO04728 at 0x29ed7503508>,
#  <Gene RTMO03022 at 0x29ed7a9a108>,
#  <Gene RTMO01074 at 0x29ed7a9a548>,
#  <Gene RTMO01076 at 0x29ed7a9a208>,
#  <Gene RTMO03707 at 0x29ed7a9a508>,
#  <Gene RTMO00807 at 0x29ed7a9a848>,
#  <Gene RTMO04339 at 0x29ed7a9a608>,
#  <Gene RTMO04631 at 0x29ed7a9a488>,
#  <Gene RTMO02826 at 0x29ed7a9a6c8>,
#  <Gene RTMO04632 at 0x29ed7a9a348>,
# ...

# %%
for reaction in model.reactions:
    print(reaction.gene_reaction_rule)
# Out:
# RTMO00131 or RTMO05104
# RTMO02719 or RTMO02716 or RTMO00549
# RTMO03052 or RTMO04279 or RTMO03053
# RTMO00831 or RTMO00549 or RTMO03630 or RTMO02719 or RTMO00138 or RTMO04026 or RTMO00139 or RTMO02716 or RTMO00832
# RTMO00166
# RTMO02070
# RTMO04728
# RTMO03022
# RTMO01076 or RTMO01074
# RTMO03707
# RTMO02826 or RTMO04339 or RTMO02829 or RTMO04631 or RTMO02828 or RTMO04632 or RTMO04633 or RTMO00807 or RTMO04657
# RTMO04657 or RTMO04339 or RTMO02826 or RTMO04631 or RTMO02829 or RTMO04632 or RTMO02828 or RTMO04633 or RTMO00807
# RTMO03024
# RTMO00197 or RTMO00196 or RTMO00193 or RTMO00194 or RTMO04075 or RTMO00373 or RTMO03395 or RTMO02535 or RTMO04972 or RTMO03714 or RTMO00200 or RTMO01034 or RTMO00201 or RTMO00199 or RTMO00198
# RTMO03749
# RTMO02237 or RTMO03852
# RTMO00694 or RTMO01425 or RTMO01424
# RTMO05248 or RTMO04294
# RTMO05248
# RTMO05022
# RTMO01680 or RTMO01679 or RTMO01678
# RTMO04916
# RTMO04294 or RTMO05248
# RTMO01021 or RTMO04555
# RTMO03749
# ...

# %% [markdown]
# Now we save the model, increasing from SBML lvl 2 to SBML lvl 3:

# %%
model = cobra.io.read_sbml_model("../model/g-thermo.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_28_c "Pyridoxal_C4H5N2O3R2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_28_c "Pyridoxal_C4H5N2O3R2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_12_c "Pyridoxal_phosphate_C4H5N2O3R2">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12_c "Pyridoxal_phosphate_C4H5N2O3R2">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_1337_c "Cob(II)yrinate-a,c-diamide">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_1337_c "Cob(II)yrinate-a,c-diamide">
# ...

# %%
cobra.io.write_sbml_model(model,"../model/g-thermo.xml")

# %% [markdown]
# Finally, let's check upper bounds:

# %%
model = cobra.io.read_sbml_model("../model/g-thermo.xml")

# %%
for reaction in model.reactions:
    print(reaction.id + " - LB: " + str(reaction.lower_bound) + " - UB: " + str(reaction.upper_bound))
# Out:
# EX_1819_e - LB: -1000.0 - UB: 10000.0
# EX_499_e - LB: -1000.0 - UB: 10000.0
# EX_23_e - LB: -1000.0 - UB: 10000.0
# EX_43_e - LB: -1000.0 - UB: 10000.0
# EX_1864_e - LB: -1000.0 - UB: 10000.0
# EX_85_e - LB: -1000.0 - UB: 10000.0
# EX_140_e - LB: -1000.0 - UB: 10000.0
# EX_408_e - LB: -1000.0 - UB: 10000.0
# EX_14_e - LB: -1000.0 - UB: 10000.0
# EX_29_e - LB: -1000.0 - UB: 10000.0
# EX_280_e - LB: -1000.0 - UB: 10000.0
# EX_1754_e - LB: -1000.0 - UB: 10000.0
# EX_1755_e - LB: -1000.0 - UB: 10000.0
# EX_1_e - LB: -1000.0 - UB: 10000.0
# EX_7_e - LB: -1000.0 - UB: 10000.0
# EX_11_e - LB: -1000.0 - UB: 10000.0
# EX_71_e - LB: -1000.0 - UB: 10000.0
# EX_209_e - LB: -1000.0 - UB: 10000.0
# EX_179_e - LB: -1000.0 - UB: 10000.0
# EX_37_e - LB: -1000.0 - UB: 10000.0
# EX_55_e - LB: -1000.0 - UB: 10000.0
# EX_45_e - LB: -1000.0 - UB: 10000.0
# EX_357_e - LB: -1000.0 - UB: 10000.0
# EX_452_e - LB: -1000.0 - UB: 10000.0
# EX_333_e - LB: -1000.0 - UB: 10000.0
# ...

# %% [markdown]
# Looking good!
